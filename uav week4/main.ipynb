# %%
from ultralytics import YOLO
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
model= YOLO("yolov8s.pt")

# %%
result=model.train(data=r"C:\Users\anamm\OneDrive\Desktop\uav week4\VizDrone_Dataset_Prepared\data.yaml",epochs=100)
# Out:
# Ultralytics 8.4.108  Python-3.11.15 torch-2.5.1 CUDA:0 (Quadro P5000, 16384MiB)
# ...
