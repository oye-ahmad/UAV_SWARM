# %%
from ultralytics import YOLO

# %%
model = YOLO(r"C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.pt")

# %%
results= model.predict(
    source=r"C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\VizDrone_Dataset_Prepared\test\images\0000071_05298_d_0000008.jpg",
    save=True,
    conf=0.3
)
# Out:
# image 1/1 C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\VizDrone_Dataset_Prepared\test\images\0000071_05298_d_0000008.jpg: 384x640 102 pedestrians, 9 peoples, 3 cars, 3 motors, 622.1ms
# Speed: 20.7ms preprocess, 622.1ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\predict-2

# %%
model.export(format="onnx")
# Out:
# Ultralytics 8.4.90  Python-3.13.5 torch-2.12.1+cpu CPU (Intel Core i5-8365U 1.60GHz)
# Model summary (fused): 73 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#
# PyTorch: starting from 'C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (85.4 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 20...
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success  5.3s, saved as 'C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.onnx' (42.7 MB)
#
# Export complete (6.7s)
# Results saved to C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.onnx
# Predict:         yolo predict task=detect model=C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.onnx imgsz=640
# ...

# %%
onnx_model = YOLO(r"C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.onnx")

onnx_model.predict(
    source=r"C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\VizDrone_Dataset_Prepared\test\images\0000071_05298_d_0000008.jpg",
    save=True
)
# Out:
# Loading C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\train-12\weights\best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.28.0 with CPUExecutionProvider
#
# image 1/1 C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\VizDrone_Dataset_Prepared\test\images\0000071_05298_d_0000008.jpg: 640x640 111 pedestrians, 10 peoples, 3 cars, 3 motors, 222.1ms
# Speed: 6.3ms preprocess, 222.1ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\MUHAMMADAHMAD\Desktop\InternShip Week 4\uav week4\uav week4\runs\detect\predict-3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pedestrian', 1: 'people', 2: 'bicycle', 3: 'car', 4: 'van', 5: 'truck', 6: 'tricycle', 7: 'awning-tricycle', 8: 'bus', 9: 'motor'}
#  obb: None
#  orig_img: array([[[ 14,   8,  39],
#          [ 18,  13,  42],
# ...
