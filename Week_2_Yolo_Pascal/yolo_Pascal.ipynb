# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")   # pretrained, transfer learning — same as your chicken project
results = model.train(data="VOC.yaml", epochs=50, imgsz=640, batch=16)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.95 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
model = YOLO(r"/content/runs/detect/train/weights/best.pt")
results = model.predict(
    source=r"/content/test.jpg",
    save=True,
    conf=0.3,
    show=True
  )
# Out:
# image 1/1 /content/test.jpg: 384x640 39 cars, 44.1ms
# Speed: 2.5ms preprocess, 44.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/predict-3
